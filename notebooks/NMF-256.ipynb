# %%
import pandas as pd
import pickle


import data_splitter as ds
import data_loader as dl
import feature_extraction as fex
# Out:
# 2023-04-16 09:27:31.464462: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-16 09:27:32.337833: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# %load_ext autoreload
# %autoreload 2

# %%
metadata = pd.read_csv('train.csv')
len(metadata.image_id.unique())
# Out:
# 54706

# %%
splitter = ds.DataSplitter(verbose=True)
# Out:
# Total patient_id in training set:  9530
# Total patient_id in test set:  2383
# Total image_id in training set:  43767
# Total image_id in test set:  10939
# Total patient_id in training set:  7624
# Total patient_id in calibration set:  1906
# Total image_id in training set:  35003
# Total image_id in calibration set:  8764

# %% [markdown]
# # Pre-train NMF on each fold's training split
#
# Using the best hyperparameters from the search using scikit-learn HalvingRandomGridSearch with NMF + logistic regression (default hyperparameters) pipeline, optimizing for average precision score.
#
#
# **Image resolution:** 256 x 256
#
# **Best hyperparameters**
# - n_components = 26
# - init = 'random'
# - beta_loss = 'kullback-leibler'
# - alpha_W (= alpha_H) = 0.9
# - l1_ratio = 0.3

# %%
# splitter.trainset is the training set in format of {patient_id: [image_id, ...]}
train_ids = splitter.trainset.keys()
label_by_img = splitter.labels

# getting cross-validation folds from training set
RANDOM_STATE = 42
cv_patient, cv_img = splitter.get_cv(n_splits=5, random_state=RANDOM_STATE)
# Out:
# Splitting training set into 5 stratified k-folds...
# --Fold:  0
# ----Total patient_id in training set:  6099
# ----Total image_id in training set:  28031
# ----Total patient_id in validation set:  1525
# ----Total image_id in validation set:  6972
# --Fold:  1
# ----Total patient_id in training set:  6099
# ----Total image_id in training set:  28016
# ----Total patient_id in validation set:  1525
# ----Total image_id in validation set:  6987
# --Fold:  2
# ----Total patient_id in training set:  6099
# ----Total image_id in training set:  27937
# ----Total patient_id in validation set:  1525
# ----Total image_id in validation set:  7066
# --Fold:  3
# ----Total patient_id in training set:  6099
# ----Total image_id in training set:  28025
# ----Total patient_id in validation set:  1525
# ----Total image_id in validation set:  6978
# --Fold:  4
# ----Total patient_id in training set:  6100
# ----Total image_id in training set:  28003
# ----Total patient_id in validation set:  1524
# ----Total image_id in validation set:  7000

# %%
for i in range(5):
    print(len(cv_img[i]['train']))
# Out:
# 28031
# 28016
# 27937
# 28025
# 28003

# %%
N_COMPONENTS = 26

BATCH_SIZE = 488 # losing as less samples as possible
IMG_SIZE = (256, 256, 1)

BASEPATH = '' # directory of images preprocessed as numpy arrays
EXTRACTOR_PATH = '../feature_extractors' # directory to save trained model

RANDOM_STATE = 42

train_time_512 = fex.cv_train_feature_extractor(
    cv_img = cv_img,
    patient_img_dict = splitter.trainset,
    batch_size = BATCH_SIZE,
    basepath = BASEPATH,
    img_size = IMG_SIZE,
    normalize = (0, 1),
    
    from_numpy = True,
    random_state = RANDOM_STATE,
    
    model_name = 'NMF',
    n_components = N_COMPONENTS,
    init = 'random',
    beta_loss= 'kullback-leibler',
    alpha_W = 0.9,
    l1_ratio = 0.3,
    
    extractor_path = EXTRACTOR_PATH,
    verbose = True,
    evaluate = False,
    return_none = True   
)
# Out:
# Fold:  0
# Initialized NMF with n_components = 26
# --Training batch  1
# --Training batch  2
# --Training batch  3
# --Training batch  4
# --Training batch  5
# --Training batch  6
# --Training batch  7
# --Training batch  8
# --Training batch  9
# --Training batch  10
# --Training batch  11
# --Training batch  12
# --Training batch  13
# --Training batch  14
# --Training batch  15
# --Training batch  16
# --Training batch  17
# --Training batch  18
# --Training batch  19
# --Training batch  20
# --Training batch  21
# --Training batch  22
# --Training batch  23
# --Training batch  24
# --Training batch  25
# --Training batch  26
# --Training batch  27
# --Training batch  28
# --Training batch  29
# --Training batch  30
# --Training batch  31
# --Training batch  32
# --Training batch  33
# --Training batch  34
# --Training batch  35
# --Training batch  36
# --Training batch  37
# --Training batch  38
# --Training batch  39
# --Training batch  40
# --Training batch  41
# --Training batch  42
# --Training batch  43
# --Training batch  44
# --Training batch  45
# --Training batch  46
# --Training batch  47
# --Training batch  48
# --Training batch  49
# --Training batch  50
# --Training batch  51
# --Training batch  52
# --Training batch  53
# --Training batch  54
# --Training batch  55
# --Training batch  56
# --Training batch  57
# -->> Training time:  -3053.588250875473
# Fold:  1
# Initialized NMF with n_components = 26
# --Training batch  1
# --Training batch  2
# --Training batch  3
# --Training batch  4
# --Training batch  5
# --Training batch  6
# --Training batch  7
# --Training batch  8
# --Training batch  9
# --Training batch  10
# --Training batch  11
# --Training batch  12
# --Training batch  13
# --Training batch  14
# --Training batch  15
# --Training batch  16
# --Training batch  17
# --Training batch  18
# --Training batch  19
# --Training batch  20
# --Training batch  21
# --Training batch  22
# --Training batch  23
# --Training batch  24
# --Training batch  25
# --Training batch  26
# --Training batch  27
# --Training batch  28
# --Training batch  29
# --Training batch  30
# --Training batch  31
# --Training batch  32
# --Training batch  33
# --Training batch  34
# --Training batch  35
# --Training batch  36
# --Training batch  37
# --Training batch  38
# --Training batch  39
# --Training batch  40
# --Training batch  41
# --Training batch  42
# --Training batch  43
# --Training batch  44
# --Training batch  45
# --Training batch  46
# --Training batch  47
# --Training batch  48
# --Training batch  49
# --Training batch  50
# --Training batch  51
# --Training batch  52
# --Training batch  53
# --Training batch  54
# --Training batch  55
# --Training batch  56
# --Training batch  57
# -->> Training time:  -2701.974259376526
# Fold:  2
# Initialized NMF with n_components = 26
# --Training batch  1
# --Training batch  2
# --Training batch  3
# --Training batch  4
# --Training batch  5
# --Training batch  6
# --Training batch  7
# --Training batch  8
# --Training batch  9
# --Training batch  10
# --Training batch  11
# --Training batch  12
# --Training batch  13
# --Training batch  14
# --Training batch  15
# --Training batch  16
# --Training batch  17
# --Training batch  18
# --Training batch  19
# --Training batch  20
# --Training batch  21
# --Training batch  22
# --Training batch  23
# --Training batch  24
# --Training batch  25
# --Training batch  26
# --Training batch  27
# --Training batch  28
# --Training batch  29
# --Training batch  30
# --Training batch  31
# --Training batch  32
# --Training batch  33
# --Training batch  34
# --Training batch  35
# --Training batch  36
# --Training batch  37
# --Training batch  38
# --Training batch  39
# --Training batch  40
# --Training batch  41
# --Training batch  42
# --Training batch  43
# --Training batch  44
# --Training batch  45
# --Training batch  46
# --Training batch  47
# --Training batch  48
# --Training batch  49
# --Training batch  50
# --Training batch  51
# --Training batch  52
# --Training batch  53
# --Training batch  54
# --Training batch  55
# --Training batch  56
# --Training batch  57
# -->> Training time:  -2832.951601266861
# Fold:  3
# Initialized NMF with n_components = 26
# --Training batch  1
# --Training batch  2
# --Training batch  3
# --Training batch  4
# --Training batch  5
# --Training batch  6
# --Training batch  7
# --Training batch  8
# --Training batch  9
# --Training batch  10
# --Training batch  11
# --Training batch  12
# --Training batch  13
# --Training batch  14
# --Training batch  15
# --Training batch  16
# --Training batch  17
# --Training batch  18
# --Training batch  19
# --Training batch  20
# --Training batch  21
# --Training batch  22
# --Training batch  23
# --Training batch  24
# --Training batch  25
# --Training batch  26
# --Training batch  27
# --Training batch  28
# --Training batch  29
# --Training batch  30
# --Training batch  31
# --Training batch  32
# --Training batch  33
# --Training batch  34
# --Training batch  35
# --Training batch  36
# --Training batch  37
# --Training batch  38
# --Training batch  39
# --Training batch  40
# --Training batch  41
# --Training batch  42
# --Training batch  43
# --Training batch  44
# --Training batch  45
# --Training batch  46
# --Training batch  47
# --Training batch  48
# --Training batch  49
# --Training batch  50
# --Training batch  51
# --Training batch  52
# --Training batch  53
# --Training batch  54
# --Training batch  55
# --Training batch  56
# --Training batch  57
# -->> Training time:  -3242.2395536899567
# Fold:  4
# Initialized NMF with n_components = 26
# --Training batch  1
# --Training batch  2
# --Training batch  3
# --Training batch  4
# --Training batch  5
# --Training batch  6
# --Training batch  7
# --Training batch  8
# --Training batch  9
# --Training batch  10
# --Training batch  11
# --Training batch  12
# --Training batch  13
# --Training batch  14
# --Training batch  15
# --Training batch  16
# --Training batch  17
# --Training batch  18
# --Training batch  19
# --Training batch  20
# --Training batch  21
# --Training batch  22
# --Training batch  23
# --Training batch  24
# --Training batch  25
# --Training batch  26
# --Training batch  27
# --Training batch  28
# --Training batch  29
# --Training batch  30
# --Training batch  31
# --Training batch  32
# --Training batch  33
# --Training batch  34
# --Training batch  35
# --Training batch  36
# --Training batch  37
# --Training batch  38
# --Training batch  39
# --Training batch  40
# --Training batch  41
# --Training batch  42
# --Training batch  43
# --Training batch  44
# --Training batch  45
# --Training batch  46
# --Training batch  47
# --Training batch  48
# --Training batch  49
# --Training batch  50
# --Training batch  51
# --Training batch  52
# --Training batch  53
# --Training batch  54
# --Training batch  55
# --Training batch  56
# --Training batch  57
# -->> Training time:  -2871.0947511196136

# %% [markdown]
# # Calculating explained variance and reconstruction error
#
# Based on the same training set that the model was trained on so that the explained variance would be comparable to the values obtained by PCA.

# %%
BATCH_SIZE = 488 # losing as less samples as possible
IMG_SIZE = (256, 256, 1)
BASEPATH = '' # directory of images preprocessed as numpy arrays

nmf_0 = pickle.load(open('../feature_extractors/NMF_26_42_256_0.pkl', 'rb'))

img_gen = dl.ImgGenerator(
                list_IDs = cv_img[0]['train'],
                patient_img_dict = splitter.trainset,
                batch_size = BATCH_SIZE,
                basepath = BASEPATH,
                img_size = IMG_SIZE,
                normalize = (0, 1),
                from_numpy = True
            )

fold_0 = fex.evaluate_feature_extractor(img_gen, nmf_0)
# Out:
# Start evaluation...
# --Transforming batch  1
# ---Reconstructing batch
# --Transforming batch  2
# ---Reconstructing batch
# --Transforming batch  3
# ---Reconstructing batch
# --Transforming batch  4
# ---Reconstructing batch
# --Transforming batch  5
# ---Reconstructing batch
# --Transforming batch  6
# ---Reconstructing batch
# --Transforming batch  7
# ---Reconstructing batch
# --Transforming batch  8
# ---Reconstructing batch
# --Transforming batch  9
# ---Reconstructing batch
# --Transforming batch  10
# ---Reconstructing batch
# --Transforming batch  11
# ---Reconstructing batch
# --Transforming batch  12
# ---Reconstructing batch
# --Transforming batch  13
# ---Reconstructing batch
# --Transforming batch  14
# ---Reconstructing batch
# --Transforming batch  15
# ---Reconstructing batch
# --Transforming batch  16
# ---Reconstructing batch
# --Transforming batch  17
# ---Reconstructing batch
# --Transforming batch  18
# ---Reconstructing batch
# --Transforming batch  19
# ---Reconstructing batch
# --Transforming batch  20
# ---Reconstructing batch
# --Transforming batch  21
# ---Reconstructing batch
# --Transforming batch  22
# ---Reconstructing batch
# --Transforming batch  23
# ---Reconstructing batch
# --Transforming batch  24
# ---Reconstructing batch
# --Transforming batch  25
# ---Reconstructing batch
# --Transforming batch  26
# ---Reconstructing batch
# --Transforming batch  27
# ---Reconstructing batch
# --Transforming batch  28
# ---Reconstructing batch
# --Transforming batch  29
# ---Reconstructing batch
# --Transforming batch  30
# ---Reconstructing batch
# --Transforming batch  31
# ---Reconstructing batch
# --Transforming batch  32
# ---Reconstructing batch
# --Transforming batch  33
# ---Reconstructing batch
# --Transforming batch  34
# ---Reconstructing batch
# --Transforming batch  35
# ---Reconstructing batch
# --Transforming batch  36
# ---Reconstructing batch
# --Transforming batch  37
# ---Reconstructing batch
# --Transforming batch  38
# ---Reconstructing batch
# --Transforming batch  39
# ---Reconstructing batch
# --Transforming batch  40
# ---Reconstructing batch
# --Transforming batch  41
# ---Reconstructing batch
# --Transforming batch  42
# ---Reconstructing batch
# --Transforming batch  43
# ---Reconstructing batch
# --Transforming batch  44
# ---Reconstructing batch
# --Transforming batch  45
# ---Reconstructing batch
# --Transforming batch  46
# ---Reconstructing batch
# --Transforming batch  47
# ---Reconstructing batch
# --Transforming batch  48
# ---Reconstructing batch
# --Transforming batch  49
# ---Reconstructing batch
# --Transforming batch  50
# ---Reconstructing batch
# --Transforming batch  51
# ---Reconstructing batch
# --Transforming batch  52
# ---Reconstructing batch
# --Transforming batch  53
# ---Reconstructing batch
# --Transforming batch  54
# ---Reconstructing batch
# --Transforming batch  55
# ---Reconstructing batch
# --Transforming batch  56
# ---Reconstructing batch
# --Transforming batch  57
# ---Reconstructing batch
# >> Calculating explained variance...
# -->  0.28884159761160055
# >> Calculating reconstruction error...
# -->  0.47032684457596124

# %%
BATCH_SIZE = 488 # losing as less samples as possible
IMG_SIZE = (256, 256, 1)
BASEPATH = '' # directory of images preprocessed as numpy arrays

nmf_1 = pickle.load(open('../feature_extractors/NMF_26_42_256_1.pkl', 'rb'))

img_gen = dl.ImgGenerator(
                list_IDs = cv_img[1]['train'],
                patient_img_dict = splitter.trainset,
                batch_size = BATCH_SIZE,
                basepath = BASEPATH,
                img_size = IMG_SIZE,
                normalize = (0, 1),
                from_numpy = True
            )

fold_1 = fex.evaluate_feature_extractor(img_gen, nmf_1)
# Out:
# Start evaluation...
# --Transforming batch  1
# ---Reconstructing batch
# --Transforming batch  2
# ---Reconstructing batch
# --Transforming batch  3
# ---Reconstructing batch
# --Transforming batch  4
# ---Reconstructing batch
# --Transforming batch  5
# ---Reconstructing batch
# --Transforming batch  6
# ---Reconstructing batch
# --Transforming batch  7
# ---Reconstructing batch
# --Transforming batch  8
# ---Reconstructing batch
# --Transforming batch  9
# ---Reconstructing batch
# --Transforming batch  10
# ---Reconstructing batch
# --Transforming batch  11
# ---Reconstructing batch
# --Transforming batch  12
# ---Reconstructing batch
# --Transforming batch  13
# ---Reconstructing batch
# --Transforming batch  14
# ---Reconstructing batch
# --Transforming batch  15
# ---Reconstructing batch
# --Transforming batch  16
# ---Reconstructing batch
# --Transforming batch  17
# ---Reconstructing batch
# --Transforming batch  18
# ---Reconstructing batch
# --Transforming batch  19
# ---Reconstructing batch
# --Transforming batch  20
# ---Reconstructing batch
# --Transforming batch  21
# ---Reconstructing batch
# --Transforming batch  22
# ---Reconstructing batch
# --Transforming batch  23
# ---Reconstructing batch
# --Transforming batch  24
# ---Reconstructing batch
# --Transforming batch  25
# ---Reconstructing batch
# --Transforming batch  26
# ---Reconstructing batch
# --Transforming batch  27
# ---Reconstructing batch
# --Transforming batch  28
# ---Reconstructing batch
# --Transforming batch  29
# ---Reconstructing batch
# --Transforming batch  30
# ---Reconstructing batch
# --Transforming batch  31
# ---Reconstructing batch
# --Transforming batch  32
# ---Reconstructing batch
# --Transforming batch  33
# ---Reconstructing batch
# --Transforming batch  34
# ---Reconstructing batch
# --Transforming batch  35
# ---Reconstructing batch
# --Transforming batch  36
# ---Reconstructing batch
# --Transforming batch  37
# ---Reconstructing batch
# --Transforming batch  38
# ---Reconstructing batch
# --Transforming batch  39
# ---Reconstructing batch
# --Transforming batch  40
# ---Reconstructing batch
# --Transforming batch  41
# ---Reconstructing batch
# --Transforming batch  42
# ---Reconstructing batch
# --Transforming batch  43
# ---Reconstructing batch
# --Transforming batch  44
# ---Reconstructing batch
# --Transforming batch  45
# ---Reconstructing batch
# --Transforming batch  46
# ---Reconstructing batch
# --Transforming batch  47
# ---Reconstructing batch
# --Transforming batch  48
# ---Reconstructing batch
# --Transforming batch  49
# ---Reconstructing batch
# --Transforming batch  50
# ---Reconstructing batch
# --Transforming batch  51
# ---Reconstructing batch
# --Transforming batch  52
# ---Reconstructing batch
# --Transforming batch  53
# ---Reconstructing batch
# --Transforming batch  54
# ---Reconstructing batch
# --Transforming batch  55
# ---Reconstructing batch
# --Transforming batch  56
# ---Reconstructing batch
# --Transforming batch  57
# ---Reconstructing batch
# >> Calculating explained variance...
# -->  0.28402679385354834
# >> Calculating reconstruction error...
# -->  0.4690774491123934

# %%
BATCH_SIZE = 488 # losing as less samples as possible
IMG_SIZE = (256, 256, 1)
BASEPATH = '' # directory of images preprocessed as numpy arrays

nmf_2 = pickle.load(open('../feature_extractors/NMF_26_42_256_2.pkl', 'rb'))

img_gen = dl.ImgGenerator(
                list_IDs = cv_img[2]['train'],
                patient_img_dict = splitter.trainset,
                batch_size = BATCH_SIZE,
                basepath = BASEPATH,
                img_size = IMG_SIZE,
                normalize = (0, 1),
                from_numpy = True
            )

fold_2 = fex.evaluate_feature_extractor(img_gen, nmf_2)
# Out:
# Start evaluation...
# --Transforming batch  1
# ---Reconstructing batch
# --Transforming batch  2
# ---Reconstructing batch
# --Transforming batch  3
# ---Reconstructing batch
# --Transforming batch  4
# ---Reconstructing batch
# --Transforming batch  5
# ---Reconstructing batch
# --Transforming batch  6
# ---Reconstructing batch
# --Transforming batch  7
# ---Reconstructing batch
# --Transforming batch  8
# ---Reconstructing batch
# --Transforming batch  9
# ---Reconstructing batch
# --Transforming batch  10
# ---Reconstructing batch
# --Transforming batch  11
# ---Reconstructing batch
# --Transforming batch  12
# ---Reconstructing batch
# --Transforming batch  13
# ---Reconstructing batch
# --Transforming batch  14
# ---Reconstructing batch
# --Transforming batch  15
# ---Reconstructing batch
# --Transforming batch  16
# ---Reconstructing batch
# --Transforming batch  17
# ---Reconstructing batch
# --Transforming batch  18
# ---Reconstructing batch
# --Transforming batch  19
# ---Reconstructing batch
# --Transforming batch  20
# ---Reconstructing batch
# --Transforming batch  21
# ---Reconstructing batch
# --Transforming batch  22
# ---Reconstructing batch
# --Transforming batch  23
# ---Reconstructing batch
# --Transforming batch  24
# ---Reconstructing batch
# --Transforming batch  25
# ---Reconstructing batch
# --Transforming batch  26
# ---Reconstructing batch
# --Transforming batch  27
# ---Reconstructing batch
# --Transforming batch  28
# ---Reconstructing batch
# --Transforming batch  29
# ---Reconstructing batch
# --Transforming batch  30
# ---Reconstructing batch
# --Transforming batch  31
# ---Reconstructing batch
# --Transforming batch  32
# ---Reconstructing batch
# --Transforming batch  33
# ---Reconstructing batch
# --Transforming batch  34
# ---Reconstructing batch
# --Transforming batch  35
# ---Reconstructing batch
# --Transforming batch  36
# ---Reconstructing batch
# --Transforming batch  37
# ---Reconstructing batch
# --Transforming batch  38
# ---Reconstructing batch
# --Transforming batch  39
# ---Reconstructing batch
# --Transforming batch  40
# ---Reconstructing batch
# --Transforming batch  41
# ---Reconstructing batch
# --Transforming batch  42
# ---Reconstructing batch
# --Transforming batch  43
# ---Reconstructing batch
# --Transforming batch  44
# ---Reconstructing batch
# --Transforming batch  45
# ---Reconstructing batch
# --Transforming batch  46
# ---Reconstructing batch
# --Transforming batch  47
# ---Reconstructing batch
# --Transforming batch  48
# ---Reconstructing batch
# --Transforming batch  49
# ---Reconstructing batch
# --Transforming batch  50
# ---Reconstructing batch
# --Transforming batch  51
# ---Reconstructing batch
# --Transforming batch  52
# ---Reconstructing batch
# --Transforming batch  53
# ---Reconstructing batch
# --Transforming batch  54
# ---Reconstructing batch
# --Transforming batch  55
# ---Reconstructing batch
# --Transforming batch  56
# ---Reconstructing batch
# --Transforming batch  57
# ---Reconstructing batch
# >> Calculating explained variance...
# -->  0.35628156986081166
# >> Calculating reconstruction error...
# -->  0.4616180646816776

# %%
BATCH_SIZE = 488 # losing as less samples as possible
IMG_SIZE = (256, 256, 1)
BASEPATH = '' # directory of images preprocessed as numpy arrays

nmf_3 = pickle.load(open('../feature_extractors/NMF_26_42_256_3.pkl', 'rb'))

img_gen = dl.ImgGenerator(
                list_IDs = cv_img[3]['train'],
                patient_img_dict = splitter.trainset,
                batch_size = BATCH_SIZE,
                basepath = BASEPATH,
                img_size = IMG_SIZE,
                normalize = (0, 1),
                from_numpy = True
            )

fold_3 = fex.evaluate_feature_extractor(img_gen, nmf_3)
# Out:
# Start evaluation...
# --Transforming batch  1
# ---Reconstructing batch
# --Transforming batch  2
# ---Reconstructing batch
# --Transforming batch  3
# ---Reconstructing batch
# --Transforming batch  4
# ---Reconstructing batch
# --Transforming batch  5
# ---Reconstructing batch
# --Transforming batch  6
# ---Reconstructing batch
# --Transforming batch  7
# ---Reconstructing batch
# --Transforming batch  8
# ---Reconstructing batch
# --Transforming batch  9
# ---Reconstructing batch
# --Transforming batch  10
# ---Reconstructing batch
# --Transforming batch  11
# ---Reconstructing batch
# --Transforming batch  12
# ---Reconstructing batch
# --Transforming batch  13
# ---Reconstructing batch
# --Transforming batch  14
# ---Reconstructing batch
# --Transforming batch  15
# ---Reconstructing batch
# --Transforming batch  16
# ---Reconstructing batch
# --Transforming batch  17
# ---Reconstructing batch
# --Transforming batch  18
# ---Reconstructing batch
# --Transforming batch  19
# ---Reconstructing batch
# --Transforming batch  20
# ---Reconstructing batch
# --Transforming batch  21
# ---Reconstructing batch
# --Transforming batch  22
# ---Reconstructing batch
# --Transforming batch  23
# ---Reconstructing batch
# --Transforming batch  24
# ---Reconstructing batch
# --Transforming batch  25
# ---Reconstructing batch
# --Transforming batch  26
# ---Reconstructing batch
# --Transforming batch  27
# ---Reconstructing batch
# --Transforming batch  28
# ---Reconstructing batch
# --Transforming batch  29
# ---Reconstructing batch
# --Transforming batch  30
# ---Reconstructing batch
# --Transforming batch  31
# ---Reconstructing batch
# --Transforming batch  32
# ---Reconstructing batch
# --Transforming batch  33
# ---Reconstructing batch
# --Transforming batch  34
# ---Reconstructing batch
# --Transforming batch  35
# ---Reconstructing batch
# --Transforming batch  36
# ---Reconstructing batch
# --Transforming batch  37
# ---Reconstructing batch
# --Transforming batch  38
# ---Reconstructing batch
# --Transforming batch  39
# ---Reconstructing batch
# --Transforming batch  40
# ---Reconstructing batch
# --Transforming batch  41
# ---Reconstructing batch
# --Transforming batch  42
# ---Reconstructing batch
# --Transforming batch  43
# ---Reconstructing batch
# --Transforming batch  44
# ---Reconstructing batch
# --Transforming batch  45
# ---Reconstructing batch
# --Transforming batch  46
# ---Reconstructing batch
# --Transforming batch  47
# ---Reconstructing batch
# --Transforming batch  48
# ---Reconstructing batch
# --Transforming batch  49
# ---Reconstructing batch
# --Transforming batch  50
# ---Reconstructing batch
# --Transforming batch  51
# ---Reconstructing batch
# --Transforming batch  52
# ---Reconstructing batch
# --Transforming batch  53
# ---Reconstructing batch
# --Transforming batch  54
# ---Reconstructing batch
# --Transforming batch  55
# ---Reconstructing batch
# --Transforming batch  56
# ---Reconstructing batch
# --Transforming batch  57
# ---Reconstructing batch
# >> Calculating explained variance...
# -->  0.35698260835046547
# >> Calculating reconstruction error...
# -->  0.45956345695489925

# %%
BATCH_SIZE = 488 # losing as less samples as possible
IMG_SIZE = (256, 256, 1)
BASEPATH = '' # directory of images preprocessed as numpy arrays

nmf_4 = pickle.load(open('../feature_extractors/NMF_26_42_256_4.pkl', 'rb'))

img_gen = dl.ImgGenerator(
                list_IDs = cv_img[4]['train'],
                patient_img_dict = splitter.trainset,
                batch_size = BATCH_SIZE,
                basepath = BASEPATH,
                img_size = IMG_SIZE,
                normalize = (0, 1),
                from_numpy = True
            )

fold_4 = fex.evaluate_feature_extractor(img_gen, nmf_4)
# Out:
# Start evaluation...
# --Transforming batch  1
# ---Reconstructing batch
# --Transforming batch  2
# ---Reconstructing batch
# --Transforming batch  3
# ---Reconstructing batch
# --Transforming batch  4
# ---Reconstructing batch
# --Transforming batch  5
# ---Reconstructing batch
# --Transforming batch  6
# ---Reconstructing batch
# --Transforming batch  7
# ---Reconstructing batch
# --Transforming batch  8
# ---Reconstructing batch
# --Transforming batch  9
# ---Reconstructing batch
# --Transforming batch  10
# ---Reconstructing batch
# --Transforming batch  11
# ---Reconstructing batch
# --Transforming batch  12
# ---Reconstructing batch
# --Transforming batch  13
# ---Reconstructing batch
# --Transforming batch  14
# ---Reconstructing batch
# --Transforming batch  15
# ---Reconstructing batch
# --Transforming batch  16
# ---Reconstructing batch
# --Transforming batch  17
# ---Reconstructing batch
# --Transforming batch  18
# ---Reconstructing batch
# --Transforming batch  19
# ---Reconstructing batch
# --Transforming batch  20
# ---Reconstructing batch
# --Transforming batch  21
# ---Reconstructing batch
# --Transforming batch  22
# ---Reconstructing batch
# --Transforming batch  23
# ---Reconstructing batch
# --Transforming batch  24
# ---Reconstructing batch
# --Transforming batch  25
# ---Reconstructing batch
# --Transforming batch  26
# ---Reconstructing batch
# --Transforming batch  27
# ---Reconstructing batch
# --Transforming batch  28
# ---Reconstructing batch
# --Transforming batch  29
# ---Reconstructing batch
# --Transforming batch  30
# ---Reconstructing batch
# --Transforming batch  31
# ---Reconstructing batch
# --Transforming batch  32
# ---Reconstructing batch
# --Transforming batch  33
# ---Reconstructing batch
# --Transforming batch  34
# ---Reconstructing batch
# --Transforming batch  35
# ---Reconstructing batch
# --Transforming batch  36
# ---Reconstructing batch
# --Transforming batch  37
# ---Reconstructing batch
# --Transforming batch  38
# ---Reconstructing batch
# --Transforming batch  39
# ---Reconstructing batch
# --Transforming batch  40
# ---Reconstructing batch
# --Transforming batch  41
# ---Reconstructing batch
# --Transforming batch  42
# ---Reconstructing batch
# --Transforming batch  43
# ---Reconstructing batch
# --Transforming batch  44
# ---Reconstructing batch
# --Transforming batch  45
# ---Reconstructing batch
# --Transforming batch  46
# ---Reconstructing batch
# --Transforming batch  47
# ---Reconstructing batch
# --Transforming batch  48
# ---Reconstructing batch
# --Transforming batch  49
# ---Reconstructing batch
# --Transforming batch  50
# ---Reconstructing batch
# --Transforming batch  51
# ---Reconstructing batch
# --Transforming batch  52
# ---Reconstructing batch
# --Transforming batch  53
# ---Reconstructing batch
# --Transforming batch  54
# ---Reconstructing batch
# --Transforming batch  55
# ---Reconstructing batch
# --Transforming batch  56
# ---Reconstructing batch
# --Transforming batch  57
# ---Reconstructing batch
# >> Calculating explained variance...
# -->  0.2997376483282446
# >> Calculating reconstruction error...
# -->  0.46807919809101595
